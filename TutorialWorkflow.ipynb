# %% [markdown]
# <a href="https://colab.research.google.com/github/Dolfino/.is-a-dev-/blob/main/TutorialWorkflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Professional XGBoost Workflow For Beginners with GPU-acceleration
#
# ## 👋 Introduction
#
# In this notebook, we’ll build a real-world machine learning workflow using the full <a href="https://data.cityofnewyork.us/Transportation/2023-Yellow-Taxi-Trip-Data/4b4i-vvec/about_data" target="_blank">2023 Yellow Taxi Trip Data from the City of New York</a>, or a smaller version of it located in the current directory: **Distilled_2023_Yellow_Taxi_Trip_Data.csv**.
#
# Instead of "hello world" examples, we’ll use millions of real taxi rides to explore what actually makes people tip more in taxis — distance, time of day, passengers, or something else? Step by step, we’ll clean and prepare the data, handle missing values and anomalies, and train an XGBoost model on GPU using cuDF Pandas and RAPIDS RMM for memory management.
#
# I hope this notebook brings you clarity, confidence, and inspiration on your data-science journey - keep learning and exploring! 🚀
#
# ## ⚙️ Manage GPU Memory
#
# When working with large datasets, we need to manage how memory is distributed between different parts of the workflow. Since we’re running everything on the GPU, we can use **RAPIDS Memory Manager (RMM)** to control how VRAM is allocated — deciding which module gets what, and keeping our workflow stable and efficient.
#
# Below, we set the `initial_pool_size` to about half of your GPU’s total VRAM. For example: if you have RTX 4080 with 16GB of VRAM - then set `initial_pool_size="8GB"`.
#
# When we do so, we allocate half of our memory to cuDF Pandas, and leave the rest of it available. cuDF pandas is using RMM by default, so if we restrict the RMM memory pool, it also restricts cuDF Pandas. XGBoost is not using RMM by default, but we can set it up to.

# %%
import condacolab
condacolab.check()
# Remove a trava de versão do Python que está causando o conflito
# !rm -f /usr/local/conda-meta/pinned
# !mamba install -y -c rapidsai -c conda-forge -c nvidia rapids=24.04 cuda-version=12.2
# Out:
# ✨🍰✨ Everything looks OK!
#
# Looking for: ['rapids=24.04', 'cuda-version=12.2']
#
# rapidsai/linux-64                                           Using cache
# rapidsai/noarch                                             Using cache
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# nvidia/linux-64                                             Using cache
# nvidia/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.11.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - rapids=24.04
#    - cuda-version=12.2
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                               Version  Build                                Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + cuda-version                           12.2  he2b69de_3                           conda-forge     Cached
#   + poppler-data                         0.4.12  hd8ed1ab_0                           conda-forge     Cached
#   + font-ttf-dejavu-sans-mono              2.37  hab24e00_0                           conda-forge     Cached
#   + font-ttf-inconsolata                  3.000  h77eed37_0                           conda-forge     Cached
#   + font-ttf-source-code-pro              2.038  h77eed37_0                           conda-forge     Cached
#   + font-ttf-ubuntu                        0.83  h77eed37_3                           conda-forge     Cached
#   + cuda-nvvm-dev_linux-64             12.2.140  ha770c72_1                           conda-forge     Cached
#   + cuda-crt-dev_linux-64              12.2.140  ha770c72_1                           conda-forge     Cached
#   + cuda-cudart-static_linux-64        12.2.140  h59595ed_0                           conda-forge     Cached
#   + cuda-cccl_linux-64                 12.2.140  ha770c72_0                           conda-forge     Cached
#   + cuda-cudart_linux-64               12.2.140  h59595ed_0                           conda-forge     Cached
#   + fonts-conda-forge                         1  hc364b38_1                           conda-forge     Cached
#   + cuda-nvcc-dev_linux-64             12.2.140  ha770c72_1                           conda-forge     Cached
#   + cuda-cudart-dev_linux-64           12.2.140  h59595ed_0                           conda-forge     Cached
#   + fonts-conda-ecosystem                     1  0                                    conda-forge     Cached
#   + icu                                    73.2  h59595ed_0                           conda-forge     Cached
#   + liblzma-devel                         5.6.3  hb9d3cd8_1                           conda-forge     Cached
#   + xz-gpl-tools                          5.6.3  hbcc6ac9_1                           conda-forge     Cached
#   + xz-tools                              5.6.3  hb9d3cd8_1                           conda-forge     Cached
#   + libabseil                        20240116.2  cxx17_he02047a_1                     conda-forge     Cached
#   + libdeflate                             1.19  hd590300_0                           conda-forge     Cached
#   + lerc                                  4.1.0  hdb68285_0                           conda-forge     Cached
#   + libjpeg-turbo                         3.1.2  hb03c661_0                           conda-forge     Cached
#   + libwebp-base                          1.3.2  hd590300_1                           conda-forge     Cached
#   + libgfortran5                         14.2.0  hf1ad2bd_2                           conda-forge     Cached
#   + dlpack                                  0.8  h59595ed_3                           conda-forge     Cached
#   + gtest                                1.17.0  h84d6215_1                           conda-forge     Cached
#   + libbrotlicommon                       1.1.0  hb9d3cd8_2                           conda-forge     Cached
#   + aws-c-common                         0.9.17  h4ab18f5_0                           conda-forge     Cached
#   + libcrc32c                             1.1.2  h9c3ff4c_0                           conda-forge     Cached
#   + snappy                                1.2.2  h03e3b7b_1                           conda-forge     Cached
#   + gflags                                2.2.2  h5888daf_1005                        conda-forge     Cached
#   + jbig                                    2.1  h7f98852_2003                        conda-forge     Cached
#   + libuv                                1.48.0  hd590300_0                           conda-forge     Cached
#   + geos                                 3.12.1  h59595ed_0                           conda-forge     Cached
#   + libnl                                3.11.0  hb9d3cd8_0                           conda-forge     Cached
#   + yaml                                  0.2.5  h280c20c_3                           conda-forge     Cached
#   + expat                                 2.6.4  h5888daf_0                           conda-forge     Cached
#   + nspr                                   4.38  h29cc59b_0                           conda-forge     Cached
#   + qhull                                2020.2  h434a139_5                           conda-forge     Cached
#   + pthread-stubs                           0.4  hb9d3cd8_1002                        conda-forge     Cached
#   + xorg-libxau                          1.0.12  hb03c661_1                           conda-forge     Cached
#   + xorg-libxdmcp                         1.1.5  hb03c661_1                           conda-forge     Cached
#   + giflib                                5.2.2  hd590300_0                           conda-forge     Cached
#   + libntlm                                 1.8  hb9d3cd8_0                           conda-forge     Cached
#   + gettext-tools                        0.25.1  h5888daf_0                           conda-forge     Cached
#   + libasprintf                          0.25.1  h8e693c7_0                           conda-forge     Cached
#   + libgettextpo                         0.25.1  h5888daf_0                           conda-forge     Cached
#   + json-c                                 0.17  h1220068_1                           conda-forge     Cached
#   + libaec                                1.1.5  h088129d_0                           conda-forge     Cached
#   + libattr                               2.5.2  hb03c661_1                           conda-forge     Cached
#   + libutf8proc                           2.8.0  hf23e847_1                           conda-forge     Cached
#   + pixman                               0.46.4  h54a6638_1                           conda-forge     Cached
#   + xorg-libice                           1.1.2  hb9d3cd8_0                           conda-forge     Cached
#   + xorg-renderproto                     0.11.1  hb9d3cd8_1003                        conda-forge     Cached
#   + xorg-xextproto                        7.3.0  hb9d3cd8_1004                        conda-forge     Cached
#   + xorg-kbproto                          1.0.7  hb9d3cd8_1003                        conda-forge     Cached
#   + xorg-xproto                          7.0.31  hb9d3cd8_1008                        conda-forge     Cached
#   + libsodium                            1.0.20  h4ab18f5_0                           conda-forge     Cached
#   + tzcode                                2026a  h280c20c_0                           conda-forge     Cached
#   + libboost-headers                     1.90.0  ha770c72_1                           conda-forge     Cached
#   + uriparser                             0.9.8  hac33072_0                           conda-forge     Cached
#   + libnvjpeg                          12.2.2.4  h59595ed_0                           conda-forge     Cached
#   + libcufile                          1.7.2.10  hd3aeb46_0                           conda-forge     Cached
#   + cuda-nvvm-tools                    12.2.140  h59595ed_1                           conda-forge     Cached
#   + cuda-crt-tools                     12.2.140  ha770c72_1                           conda-forge     Cached
#   + cuda-nvvm-impl                     12.2.140  h59595ed_1                           conda-forge     Cached
#   + libcufft                         11.0.8.103  hd3aeb46_0                           conda-forge     Cached
#   + nvcomp                                3.0.6  h10b603f_0                           conda-forge     Cached
#   + cuda-nvrtc                         12.2.140  hd3aeb46_0                           conda-forge     Cached
#   + libnvjitlink                        12.9.86  hecca717_2                           conda-forge     Cached
#   + nccl                               2.29.3.1  h4d09622_0                           conda-forge     Cached
#   + libcurand                        10.3.3.141  hd3aeb46_0                           conda-forge     Cached
#   + cuda-cudart-static                 12.2.140  hd3aeb46_0                           conda-forge     Cached
#   + cuda-cudart                        12.2.140  hd3aeb46_0                           conda-forge     Cached
#   + spdlog                               1.12.0  hd2e6256_2                           conda-forge     Cached
#   + pcre2                                 10.42  hcad00b1_0                           conda-forge     Cached
#   + libpng                               1.6.43  h2797004_0                           conda-forge     Cached
#   + libllvm14                            14.0.6  hcd5def8_4                           conda-forge     Cached
#   + zlib                                 1.2.13  h4ab18f5_6                           conda-forge     Cached
#   + xz                                    5.6.3  hbcc6ac9_1                           conda-forge     Cached
#   + libre2-11                        2023.09.01  h5a48ba9_2                           conda-forge     Cached
#   + libprotobuf                          4.25.3  h08a7969_0                           conda-forge     Cached
#   + hdf4                                 4.2.15  h2a13503_7                           conda-forge     Cached
#   + libgfortran                          14.2.0  h69a702a_2                           conda-forge     Cached
#   + gmock                                1.17.0  ha770c72_1                           conda-forge     Cached
#   + libbrotlienc                          1.1.0  hb9d3cd8_2                           conda-forge     Cached
#   + libbrotlidec                          1.1.0  hb9d3cd8_2                           conda-forge     Cached
#   + aws-c-compression                    0.2.18  h36a0aea_4                           conda-forge     Cached
#   + aws-c-sdkutils                       0.1.16  h36a0aea_0                           conda-forge     Cached
#   + aws-checksums                        0.1.18  h36a0aea_4                           conda-forge     Cached
#   + blosc                                1.21.5  hc2324a3_1                           conda-forge     Cached
#   + glog                                  0.7.1  hbabe93e_0                           conda-forge     Cached
#   + librttopo                             1.1.0  h8917695_15                          conda-forge     Cached
#   + libxcb                                 1.15  h0b41bf4_0                           conda-forge     Cached
#   + libasprintf-devel                    0.25.1  h8e693c7_0                           conda-forge     Cached
#   + libgettextpo-devel                   0.25.1  h5888daf_0                           conda-forge     Cached
#   + attr                                  2.5.2  hb03c661_1                           conda-forge     Cached
#   + xorg-libsm                            1.2.6  he73a12e_0                           conda-forge     Cached
#   + zeromq                                4.3.5  h387f397_9                           conda-forge     Cached
#   + libkml                                1.3.0  h01aab08_1018                        conda-forge     Cached
#   + libcufile-dev                      1.7.2.10  hd3aeb46_0                           conda-forge     Cached
#   + cuda-nvcc-tools                    12.2.140  hd3aeb46_1                           conda-forge     Cached
#   + libcublas                          12.2.5.6  hd3aeb46_0                           conda-forge     Cached
#   + libcusparse                      12.1.2.141  hd3aeb46_0                           conda-forge     Cached
#   + libcurand-dev                    10.3.3.141  hd3aeb46_0                           conda-forge     Cached
#   + libzip                               1.10.1  h2629f0a_3                           conda-forge     Cached
#   + libevent                             2.1.12  hf998b51_1                           conda-forge     Cached
#   + libpq                                  16.3  ha72fbe1_0                           conda-forge     Cached
#   + cyrus-sasl                           2.1.28  hd9c7081_0                           conda-forge     Cached
#   + s2n                                  1.4.13  he19d79f_0                           conda-forge     Cached
#   + aws-c-cal                            0.6.12  h2ba76a8_0                           conda-forge     Cached
#   + cuda-cudart-dev                    12.2.140  hd3aeb46_0                           conda-forge     Cached
#   + freetype                             2.12.1  h267a509_2                           conda-forge     Cached
#   + nodejs                              20.12.2  hb753e55_0                           conda-forge     Cached
#   + nss                                   3.100  hca3bf56_0                           conda-forge     Cached
#   + sqlite                               3.46.0  h6d4b2fc_0                           conda-forge     Cached
#   + minizip                               4.0.6  h9d307f2_0                           conda-forge     Cached
#   + libtiff                               4.6.0  ha9c0a0a_2                           conda-forge     Cached
#   + re2                              2023.09.01  h7f4b329_2                           conda-forge     Cached
#   + orc                                   2.0.0  h17fec99_1                           conda-forge     Cached
#   + libgfortran-ng                       14.2.0  h69a702a_2                           conda-forge     Cached
#   + libopenblas                          0.3.29  pthreads_h94d23a6_0                  conda-forge     Cached
#   + brotli-bin                            1.1.0  hb9d3cd8_2                           conda-forge     Cached
#   + xorg-libx11                           1.8.9  h8ee46fc_0                           conda-forge     Cached
#   + gettext                              0.25.1  h5888daf_0                           conda-forge     Cached
#   + libcap                                 2.77  h3ff7636_0                           conda-forge     Cached
#   + libcublas-dev                      12.2.5.6  hd3aeb46_0                           conda-forge     Cached
#   + libcusparse-dev                  12.1.2.141  hd3aeb46_0                           conda-forge     Cached
#   + libcusolver                      11.5.2.141  hd3aeb46_0                           conda-forge     Cached
#   + libthrift                            0.19.0  hb90f79a_1                           conda-forge     Cached
#   + aws-c-io                             0.14.8  h96d4d28_0                           conda-forge     Cached
#   + cuda-profiler-api                  12.2.140  ha770c72_0                           conda-forge     Cached
#   + cuda-nvcc-impl                     12.2.140  hd3aeb46_1                           conda-forge     Cached
#   + fontconfig                           2.14.2  h14ed4e7_0                           conda-forge     Cached
#   + freexl                                2.0.0  h743c826_0                           conda-forge     Cached
#   + openjpeg                              2.5.2  h488ebb8_0                           conda-forge     Cached
#   + lcms2                                  2.16  hb7c19ff_0                           conda-forge     Cached
#   + libwebp                               1.3.2  h658648e_1                           conda-forge     Cached
#   + rpds-py                              0.30.0  py311h902ca64_0                      conda-forge     Cached
#   + argon2-cffi-bindings                 25.1.0  py311h49ec1c0_2                      conda-forge     Cached
#   + markupsafe                            3.0.3  py311h3778330_1                      conda-forge     Cached
#   + pyzmq                                27.1.0  py311h57d2397_2                      conda-forge     Cached
#   + unicodedata2                         17.0.1  py311h49ec1c0_0                      conda-forge     Cached
#   + kiwisolver                            1.5.0  py311h724c32c_0                      conda-forge     Cached
#   + lz4                                   4.3.3  py311h2cbdf9a_1                      conda-forge     Cached
#   + pyyaml                                6.0.3  py311h3778330_1                      conda-forge     Cached
#   + psutil                                7.2.2  py311haee01d2_0                      conda-forge     Cached
#   + msgpack-python                        1.1.2  py311hdf67eae_1                      conda-forge     Cached
#   + tornado                               6.5.4  py311h41d9c34_0                      conda-forge     Cached
#   + websockets                             10.4  py311hd4cff14_1                      conda-forge     Cached
#   + propcache                             0.3.1  py311h2dc5d0c_0                      conda-forge     Cached
#   + multidict                             6.7.1  py311h3778330_0                      conda-forge     Cached
#   + frozenlist                            1.7.0  py311h52bc045_0                      conda-forge     Cached
#   + fastrlock                             0.8.3  py311hc665b79_2                      conda-forge     Cached
#   + llvmlite                             0.42.0  py311ha6695c7_1                      conda-forge     Cached
#   + protobuf                             4.25.3  py311hbffca5d_1                      conda-forge     Cached
#   + nvtx                                 0.2.15  py311h49ec1c0_0                      conda-forge     Cached
#   + libllvm15                            15.0.7  hb3ce162_4                           conda-forge     Cached
#   + tiledb                               2.18.2  h99f50a1_1                           conda-forge     Cached
#   + postgresql                             16.3  h8e811e2_0                           conda-forge     Cached
#   + libgrpc                              1.62.2  h15f2491_0                           conda-forge     Cached
#   + libblas                               3.9.0  31_h59b9bed_openblas                 conda-forge     Cached
#   + brotli                                1.1.0  hb9d3cd8_2                           conda-forge     Cached
#   + xorg-libxext                          1.3.4  h0b41bf4_2                           conda-forge     Cached
#   + xorg-libxrender                      0.9.11  hd590300_0                           conda-forge     Cached
#   + libglib                              2.78.4  h783c2da_0                           conda-forge     Cached
#   + libudev1                                260  h6569c3e_0                           conda-forge     Cached
#   + libsystemd0                             260  h6569c3e_0                           conda-forge     Cached
#   + libcusolver-dev                  11.5.2.141  hd3aeb46_0                           conda-forge     Cached
#   + aws-c-http                            0.8.1  h63f54a0_13                          conda-forge     Cached
#   + aws-c-event-stream                    0.4.2  h161de36_10                          conda-forge     Cached
#   + hdf5                                 1.14.3  nompi_hdf9ad27_105                   conda-forge     Cached
#   + xerces-c                              3.2.5  hac6953d_0                           conda-forge     Cached
#   + cfitsio                               4.3.1  hbdc6101_0                           conda-forge     Cached
#   + librdkafka                            1.9.2  ha5a0de0_2                           conda-forge     Cached
#   + proj                                  9.3.0  h1d62c97_2                           conda-forge     Cached
#   + pillow                               10.3.0  py311h18e6fac_0                      conda-forge     Cached
#   + yarl                                 1.23.0  py311h3778330_0                      conda-forge     Cached
#   + libgoogle-cloud                      2.23.0  h9be4e54_1                           conda-forge     Cached
#   + libcblas                              3.9.0  31_he106b2a_openblas                 conda-forge     Cached
#   + liblapack                             3.9.0  31_h7ac8fdf_openblas                 conda-forge     Cached
#   + cairo                                1.18.0  h3faef2a_0                           conda-forge     Cached
#   + rdma-core                              61.0  h192683f_0                           conda-forge     Cached
#   + aws-c-mqtt                           0.10.4  hcc7299c_2                           conda-forge     Cached
#   + aws-c-auth                           0.7.20  h5f1c8d9_0                           conda-forge     Cached
#   + libnetcdf                             4.9.2  nompi_h135f659_114                   conda-forge     Cached
#   + kealib                                1.5.3  hf8d3e68_2                           conda-forge     Cached
#   + python-confluent-kafka                1.9.2  py311hd4cff14_2                      conda-forge     Cached
#   + libspatialite                         5.1.0  h72606ae_3                           conda-forge     Cached
#   + geotiff                               1.7.1  hf074850_14                          conda-forge     Cached
#   + libgoogle-cloud-storage              2.23.0  hc7a4891_1                           conda-forge     Cached
#   + numpy                                1.26.4  py311h64a7726_0                      conda-forge     Cached
#   + poppler                             23.12.0  h590f24d_0                           conda-forge     Cached
#   + ucx                                  1.15.0  hda83522_8                           conda-forge     Cached
#   + aws-c-s3                              0.5.9  h10bd90f_0                           conda-forge     Cached
#   + imagecodecs-lite                  2019.12.3  py311h18e1886_8                      conda-forge     Cached
#   + pywavelets                            1.9.0  py311h0372a8f_2                      conda-forge     Cached
#   + contourpy                             1.3.3  py311h724c32c_4                      conda-forge     Cached
#   + shapely                               2.0.4  py311h0bed3d6_1                      conda-forge     Cached
#   + scipy                                1.16.0  py311h2d3ef60_0                      conda-forge     Cached
#   + cupy-core                            13.6.0  py311he30c881_2                      conda-forge     Cached
#   + numba                                0.59.1  py311h96b013e_0                      conda-forge     Cached
#   + libgdal                               3.8.1  h4b8bffa_3                           conda-forge     Cached
#   + aws-crt-cpp                          0.26.8  h4f3a3cc_11                          conda-forge     Cached
#   + treelite                              4.1.2  py311he8f9275_2                      conda-forge     Cached
#   + cupy                                 13.6.0  py311h72da3fd_2                      conda-forge     Cached
#   + gdal                                  3.8.1  py311h39b4e0e_3                      conda-forge     Cached
#   + aws-sdk-cpp                        1.11.267  h51dfee4_8                           conda-forge     Cached
#   + pyogrio                               0.7.2  py311hf8e0aa6_1                      conda-forge     Cached
#   + libarrow                             14.0.2  hefa796f_19_cpu                      conda-forge     Cached
#   + libparquet                           14.0.2  hacf5a1f_19_cpu                      conda-forge     Cached
#   + libarrow-gandiva                     14.0.2  hc1954e9_19_cpu                      conda-forge     Cached
#   + libarrow-flight                      14.0.2  hc4f8a93_19_cpu                      conda-forge     Cached
#   + libarrow-acero                       14.0.2  hbabe93e_19_cpu                      conda-forge     Cached
#   + libarrow-flight-sql                  14.0.2  he4f5ca8_19_cpu                      conda-forge     Cached
#   + libarrow-dataset                     14.0.2  hbabe93e_19_cpu                      conda-forge     Cached
#   + libarrow-substrait                   14.0.2  he4f5ca8_19_cpu                      conda-forge     Cached
#   + pyarrow                              14.0.2  py311hd5e4297_19_cpu                 conda-forge     Cached
#   + ucx-proc                              1.0.0  gpu                                  rapidsai        Cached
#   + libxgboost                            2.0.3  rapidsai_hea4bf7d_2                  rapidsai        Cached
#   + librmm                             24.04.00  cuda12_240410_g8f19c9c3_0            rapidsai        Cached
#   + libcucim                           24.04.00  cuda12_240410_ga24abfd_0             rapidsai        Cached
#   + libkvikio                          24.04.00  cuda12_240410_gfb767d7_0             rapidsai        Cached
#   + pynvjitlink                           0.7.0  12.9_py311_250625_3693c9cd_hd6618c4  rapidsai        Cached
#   + libraft-headers-only               24.04.00  cuda12_240410_gfa44bcc8_0            rapidsai        Cached
#   + libcudf                            24.04.01  cuda12_240501_gaf9fd840f2_0          rapidsai        Cached
#   + libraft-headers                    24.04.00  cuda12_240410_gfa44bcc8_0            rapidsai        Cached
#   + libcudf_kafka                      24.04.01  cuda12_240501_gaf9fd840f2_0          rapidsai        Cached
#   + libcuspatial                       24.04.00  cuda12_240410_g7da37aae_0            rapidsai        Cached
#   + libraft                            24.04.00  cuda12_240410_gfa44bcc8_0            rapidsai        Cached
#   + libcugraphops                      24.04.00  cuda12_240410_g021aa305_0            nvidia          Cached
#   + libcumlprims                       24.04.00  cuda12_240410_gfae5daf_0             nvidia          Cached
#   + lark                                  1.3.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + cached_property                       1.5.2  pyha770c72_1                         conda-forge     Cached
#   + webcolors                           25.10.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + uri-template                          1.3.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + python-json-logger                    2.0.7  pyhd8ed1ab_0                         conda-forge     Cached
#   + rfc3986-validator                     0.1.1  pyh9f0ad1d_0                         conda-forge     Cached
#   + pyee                                  8.1.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + soupsieve                             2.8.3  pyhd8ed1ab_0                         conda-forge     Cached
#   + pandocfilters                         1.5.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + defusedxml                            0.7.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + python-fastjsonschema                2.21.2  pyhe01879c_0                         conda-forge     Cached
#   + typing_utils                          0.1.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + ptyprocess                            0.7.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + threadpoolctl                         3.6.0  pyhecae5ae_0                         conda-forge     Cached
#   + websocket-client                      1.9.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + send2trash                            2.1.0  pyha191276_1                         conda-forge     Cached
#   + prometheus_client                    0.24.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + munkres                               1.1.4  pyhd8ed1ab_1                         conda-forge     Cached
#   + pyparsing                             3.3.2  pyhcf101f3_0                         conda-forge     Cached
#   + cycler                               0.12.1  pyhcf101f3_2                         conda-forge     Cached
#   + pytz                           2026.1.post1  pyhcf101f3_0                         conda-forge     Cached
#   + python-tzdata                        2025.3  pyhd8ed1ab_0                         conda-forge     Cached
#   + webencodings                          0.5.1  pyhd8ed1ab_3                         conda-forge     Cached
#   + tblib                                 3.2.2  pyhcf101f3_0                         conda-forge     Cached
#   + sortedcontainers                      2.4.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + cloudpickle                           3.1.2  pyhcf101f3_1                         conda-forge     Cached
#   + xyzservices                       2025.11.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + colorcet                              3.1.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + zipp                                 3.23.0  pyhcf101f3_1                         conda-forge     Cached
#   + simpervisor                           1.0.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + traitlets                            5.14.3  pyhd8ed1ab_1                         conda-forge     Cached
#   + uc-micro-py                           2.0.0  pyhcf101f3_0                         conda-forge     Cached
#   + mdurl                                 0.1.2  pyhd8ed1ab_1                         conda-forge     Cached
#   + param                                 2.3.2  pyhc455866_0                         conda-forge     Cached
#   + narwhals                             2.18.0  pyhcf101f3_0                         conda-forge     Cached
#   + appdirs                               1.4.4  pyhd8ed1ab_1                         conda-forge     Cached
#   + pygments                             2.19.2  pyhd8ed1ab_0                         conda-forge     Cached
#   + toolz                                 1.1.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + six                                  1.17.0  pyhe01879c_1                         conda-forge     Cached
#   + lazy-loader                             0.5  pyhd8ed1ab_0                         conda-forge     Cached
#   + typing_extensions                    4.15.0  pyhcf101f3_0                         conda-forge     Cached
#   + click                                 8.3.1  pyh8f84b5b_1                         conda-forge     Cached
#   + networkx                              3.6.1  pyhcf101f3_0                         conda-forge     Cached
#   + aiohappyeyeballs                      2.6.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + attrs                                26.1.0  pyhcf101f3_0                         conda-forge     Cached
#   + cuda-pathfinder                       1.4.3  pyhc364b38_0                         conda-forge     Cached
#   + cachetools                            7.0.5  pyhd8ed1ab_0                         conda-forge     Cached
#   + fsspec                             2026.2.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + joblib                                1.5.3  pyhd8ed1ab_0                         conda-forge     Cached
#   + locket                                1.0.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + zict                                  3.0.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + pynvml                               11.4.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + jinja2                                3.1.6  pyhcf101f3_1                         conda-forge     Cached
#   + imageio                              2.37.0  pyhfb79c49_0                         conda-forge     Cached
#   + tifffile                           2020.6.3  py_0                                 conda-forge     Cached
#   + pyarrow-hotfix                          0.7  pyhd8ed1ab_0                         conda-forge     Cached
#   + rfc3987-syntax                        1.1.0  pyhe01879c_1                         conda-forge     Cached
#   + cached-property                       1.5.2  hd8ed1ab_1                           conda-forge     Cached
#   + overrides                             7.7.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + terminado                            0.18.1  pyhc90fa1f_1                         conda-forge     Cached
#   + tinycss2                              1.4.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + bleach                                6.3.0  pyhcf101f3_1                         conda-forge     Cached
#   + importlib-metadata                    8.8.0  pyhcf101f3_0                         conda-forge     Cached
#   + jupyter_core                          5.9.1  pyhc90fa1f_0                         conda-forge     Cached
#   + linkify-it-py                         2.1.0  pyhcf101f3_0                         conda-forge     Cached
#   + markdown-it-py                        4.0.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + pyct                                  0.6.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + pyviz_comms                           3.0.6  pyhd8ed1ab_0                         conda-forge     Cached
#   + jupyterlab_pygments                   0.3.0  pyhd8ed1ab_2                         conda-forge     Cached
#   + rfc3339-validator                     0.1.4  pyhd8ed1ab_1                         conda-forge     Cached
#   + multipledispatch                      0.6.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + python-dateutil                 2.9.0.post0  pyhe01879c_2                         conda-forge     Cached
#   + lazy_loader                             0.5  pyhd8ed1ab_0                         conda-forge     Cached
#   + mistune                               3.2.0  pyhcf101f3_0                         conda-forge     Cached
#   + exceptiongroup                        1.3.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + typing-extensions                    4.15.0  h396c80c_0                           conda-forge     Cached
#   + aiosignal                             1.4.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + referencing                          0.37.0  pyhcf101f3_0                         conda-forge     Cached
#   + partd                                 1.4.2  pyhd8ed1ab_0                         conda-forge     Cached
#   + streamz                               0.6.5  pyh332efcf_0                         conda-forge     Cached
#   + branca                                0.8.2  pyhd8ed1ab_0                         conda-forge     Cached
#   + bokeh                                 3.9.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + fqdn                                  1.5.1  pyhd8ed1ab_1                         conda-forge     Cached
#   + jupyter_server_terminals              0.5.4  pyhcf101f3_0                         conda-forge     Cached
#   + bleach-with-css                       6.3.0  hbca2aae_1                           conda-forge     Cached
#   + markdown                             3.10.2  pyhcf101f3_0                         conda-forge     Cached
#   + importlib_metadata                    8.8.0  h8f7a5dd_0                           conda-forge     Cached
#   + pyppeteer                             1.0.2  pyhd8ed1ab_1                         conda-forge     Cached
#   + mdit-py-plugins                       0.5.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + rich                                 14.3.3  pyhcf101f3_0                         conda-forge     Cached
#   + arrow                                 1.4.0  pyhcf101f3_0                         conda-forge     Cached
#   + jupyter_client                        8.8.0  pyhcf101f3_0                         conda-forge     Cached
#   + anyio                                4.12.1  pyhcf101f3_0                         conda-forge     Cached
#   + beautifulsoup4                       4.14.3  pyha770c72_0                         conda-forge     Cached
#   + argon2-cffi                          25.1.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + jsonschema-specifications          2025.9.1  pyhcf101f3_0                         conda-forge     Cached
#   + folium                               0.20.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + dask-core                          2024.1.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + isoduration                         20.11.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + jsonschema                           4.26.0  pyhcf101f3_0                         conda-forge     Cached
#   + jsonschema-with-format-nongpl        4.26.0  hcf101f3_0                           conda-forge     Cached
#   + nbformat                             5.10.4  pyhd8ed1ab_1                         conda-forge     Cached
#   + jupyter_events                       0.12.0  pyhe01879c_0                         conda-forge     Cached
#   + nbclient                             0.10.4  pyhd8ed1ab_0                         conda-forge     Cached
#   + nbconvert-core                       7.17.0  pyhcf101f3_0                         conda-forge     Cached
#   + jupyter_server                       2.17.0  pyhcf101f3_0                         conda-forge     Cached
#   + libcugraph                         24.04.00  cuda12_240410_g8d8fb74c2_0           rapidsai        Cached
#   + libcuml                            24.04.00  cuda12_240410_ge7bc67431_0           rapidsai        Cached
#   + ucx-py                              0.37.00  py311_240410_gcb8f84c_0              rapidsai        Cached
#   + libcugraph_etl                     24.04.00  cuda12_240410_g8d8fb74c2_0           rapidsai        Cached
#   + pylibcugraph                       24.04.00  cuda12_py311_240410_g8d8fb74c2_0     rapidsai        Cached
#   + nx-cugraph                         24.04.00  py311_0                              rapidsai        Cached
#   + fonttools                            4.62.0  py311h3778330_0                      conda-forge     Cached
#   + cytoolz                               1.1.0  py311h49ec1c0_2                      conda-forge     Cached
#   + cuda-bindings                        12.9.6  py311hff0572f_0                      conda-forge     Cached
#   + scikit-learn                          1.8.0  np2py311ha15b03d_1                   conda-forge     Cached
#   + pyproj                                3.6.1  py311h1facc83_4                      conda-forge     Cached
#   + pandas                                2.2.1  py311h320fe9a_0                      conda-forge     Cached
#   + aiohttp                              3.13.3  py311h55b9665_0                      conda-forge     Cached
#   + matplotlib-base                      3.10.1  py311h2b939e6_0                      conda-forge     Cached
#   + scikit-image                         0.20.0  py311h2872171_1                      conda-forge     Cached
#   + distributed                        2024.1.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + cuda-python                          12.9.6  pyh698daf1_0                         conda-forge     Cached
#   + xarray                             2025.6.1  pyhd8ed1ab_1                         conda-forge     Cached
#   + mapclassify                          2.10.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + panel                                1.8.10  pyhd8ed1ab_0                         conda-forge     Cached
#   + geopandas-base                        1.1.3  pyha770c72_0                         conda-forge     Cached
#   + jupyter-server-proxy                  4.4.0  pyhd8ed1ab_1                         conda-forge     Cached
#   + dask                               2024.1.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + datashader                           0.19.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + holoviews                            1.22.1  pyhd8ed1ab_0                         conda-forge     Cached
#   + geopandas                             1.1.3  pyhd8ed1ab_0                         conda-forge     Cached
#   + dask-expr                             0.4.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + py-xgboost                            2.0.3  rapidsai_pyhf96fb25_2                rapidsai        Cached
#   + rapids-dask-dependency             24.04.01  py_0                                 rapidsai        Cached
#   + cucim                              24.04.00  cuda12_py311_240410_ga24abfd_0       rapidsai        Cached
#   + rmm                                24.04.00  cuda12_py311_240410_g8f19c9c3_0      rapidsai        Cached
#   + xgboost                               2.0.3  rapidsai_pyhcb9e655_2                rapidsai        Cached
#   + dask-cuda                          24.04.00  py311_240410_g7ed6735_0              rapidsai        Cached
#   + cudf                               24.04.01  cuda12_py311_240501_gaf9fd840f2_0    rapidsai        Cached
#   + pylibraft                          24.04.00  cuda12_py311_240410_gfa44bcc8_0      rapidsai        Cached
#   + cuproj                             24.04.00  cuda12_py311_240410_g7da37aae_0      rapidsai        Cached
#   + rapids-xgboost                     24.04.00  cuda12_py311_240411_gb301c96_0       rapidsai        Cached
#   + cudf_kafka                         24.04.01  cuda12_py311_240501_gaf9fd840f2_0    rapidsai        Cached
#   + dask-cudf                          24.04.01  cuda12_py311_240501_gaf9fd840f2_0    rapidsai        Cached
#   + cuspatial                          24.04.00  cuda12_py311_240410_g7da37aae_0      rapidsai        Cached
#   + raft-dask                          24.04.00  cuda12_py311_240410_gfa44bcc8_0      rapidsai        Cached
#   + custreamz                          24.04.01  cuda12_py311_240501_gaf9fd840f2_0    rapidsai        Cached
#   + cuxfilter                          24.04.01  cuda12_py311_240411_g175a4dc_0       rapidsai        Cached
#   + cugraph                            24.04.00  cuda12_py311_240410_g8d8fb74c2_0     rapidsai        Cached
#   + cuml                               24.04.00  cuda12_py311_240410_ge7bc67431_0     rapidsai        Cached
#   + rapids                             24.04.00  cuda12_py311_240411_gb301c96_0       rapidsai        Cached
#
#   Upgrade:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates                  2024.12.14  hbcca054_0                           conda-forge     Cached
#   + ca-certificates                   2026.2.25  hbd8a1cb_0                           conda-forge     Cached
#   - openssl                               3.4.0  h7b32b05_1                           conda-forge     Cached
#   + openssl                               3.6.1  h35e630c_1                           conda-forge     Cached
#   - certifi                          2024.12.14  pyhd8ed1ab_0                         conda-forge     Cached
#   + certifi                           2026.2.25  pyhd8ed1ab_0                         conda-forge     Cached
#
#   Downgrade:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - fmt                                  11.0.2  h434a139_0                           conda-forge     Cached
#   + fmt                                  10.2.1  h00ab1b0_0                           conda-forge     Cached
#   - libzlib                               1.3.1  hb9d3cd8_2                           conda-forge     Cached
#   + libzlib                              1.2.13  h4ab18f5_6                           conda-forge     Cached
#   - lz4-c                                1.10.0  h5888daf_1                           conda-forge     Cached
#   + lz4-c                                 1.9.4  hcb278e6_0                           conda-forge     Cached
#   - libsqlite                            3.47.2  hee588c1_0                           conda-forge     Cached
#   + libsqlite                            3.46.0  hde9e2c9_0                           conda-forge     Cached
#   - libsolv                              0.7.30  h3509ff9_0                           conda-forge     Cached
#   + libsolv                              0.7.29  ha6fb4c9_0                           conda-forge     Cached
#   - libnghttp2                           1.64.0  h161d5f1_0                           conda-forge     Cached
#   + libnghttp2                           1.58.0  h47da74e_1                           conda-forge     Cached
#   - libssh2                              1.11.1  hf672d98_0                           conda-forge     Cached
#   + libssh2                              1.11.0  h0841786_0                           conda-forge     Cached
#   - python                              3.11.11  h9e4cc4f_1_cpython                   conda-forge     Cached
#   + python                               3.11.9  hb806964_0_cpython                   conda-forge     Cached
#   - libxml2                              2.13.5  h0d44e9d_1                           conda-forge     Cached
#   + libxml2                              2.12.7  hc051c1a_1                           conda-forge     Cached
#   - libcurl                              8.11.1  h332b0f4_0                           conda-forge     Cached
#   + libcurl                               8.8.0  hca28451_1                           conda-forge     Cached
#   - conda                               24.11.2  py311h38be061_1                      conda-forge     Cached
#   + conda                                24.7.1  py311h38be061_0                      conda-forge     Cached
#   - libarchive                            3.7.7  h4585015_3                           conda-forge     Cached
#   + libarchive                            3.7.4  hfca40fe_0                           conda-forge     Cached
#   - libmamba                             1.5.12  h49b8a8d_0                           conda-forge     Cached
#   + libmamba                              1.5.8  had39da4_0                           conda-forge     Cached
#   - libmambapy                           1.5.12  py311hb3373dd_0                      conda-forge     Cached
#   + libmambapy                            1.5.8  py311hf2555c7_0                      conda-forge     Cached
#   - mamba                                1.5.12  py311h3072747_0                      conda-forge     Cached
#   + mamba                                 1.5.8  py311h3072747_0                      conda-forge     Cached
#   - urllib3                               2.3.0  pyhd8ed1ab_0                         conda-forge     Cached
#   + urllib3                             1.26.20  pyhd8ed1ab_0                         conda-forge     Cached
#
#   Summary:
#
#   Install: 385 packages
#   Upgrade: 3 packages
#   Downgrade: 16 packages
#
#   Total download: 0 B
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Extracting  (109)  ⣾  [+] 0.1s
# Extracting  (110)  ⣾  [+] 0.2s
# Extracting  (109)  ⣾  [+] 0.3s
# Extracting  (107)  ⣾  [+] 0.4s
# Extracting  (105)  ⣾  [+] 0.5s
# Extracting  (104)  ⣾  [+] 0.6s
# Extracting  (104)  ⣾  [+] 0.7s
# Extracting  (102)  ⣾  [+] 0.8s
# Extracting  (100)  ⣾  [+] 0.9s
# Extracting  (99)  ⣾  [+] 1.0s
# Extracting  (99)  ⣾  [+] 1.1s
# Extracting  (98)  ⣾  [+] 1.2s
# ...
# Extracting  (33)  ⣾  [+] 1m:10.8s
# Extracting  (33)  ⣾  [+] 1m:10.9s
# Extracting  (33)  ⣾  [+] 1m:11.0s
# Extracting  (33)  ⣾  [+] 1m:11.1s
# Extracting  (33)  ⣾  [+] 1m:11.2s
# Extracting  (33)  ⣾  [+] 1m:11.3s
# Extracting  (33)  ⣾  [+] 1m:11.4s
# Extracting  (33)  ⣾  [+] 1m:11.5s
# Extracting  (33)  ⣾  [+] 1m:11.6s
# Extracting  (33)  ⣾  [+] 1m:11.7s
# Extracting  (33)  ⣾  [+] 1m:11.8s
# Extracting  (33)  ⣾  [+] 1m:11.9s
# Extracting  (33)  ⣾  [+] 1m:12.0s
# Extracting  (33)  ⣾  [+] 1m:12.1s
# Extracting  (33)  ⣾  [+] 1m:12.2s
# Extracting  (33)  ⣾  [+] 1m:12.3s
# Extracting  (33)  ⣾  [+] 1m:12.4s
# Extracting  (33)  ⣾  [+] 1m:12.5s
# Extracting  (33)  ⣾  [+] 1m:12.6s
# Extracting  (33)  ⣾  [+] 1m:12.7s
# Extracting  (33)  ⣾  [+] 1m:12.8s
# Extracting  (33)  ⣾  [+] 1m:12.9s
# Extracting  (33)  ⣾  [+] 1m:13.0s
# Extracting  (33)  ⣾  [+] 1m:13.1s
# Extracting  (33)  ⣾  [+] 1m:13.2s
# Extracting  (33)  ⣾  [+] 1m:13.3s
# Extracting  (33)  ⣾  [+] 1m:13.4s
# Extracting  (33)  ⣾  [+] 1m:13.5s
# Extracting  (33)  ⣾  [+] 1m:13.6s
# Extracting  (33)  ⣾  [+] 1m:13.7s
# Extracting  (33)  ⣾  [+] 1m:13.8s
# Extracting  (33)  ⣾  [+] 1m:13.9s
# Extracting  (33)  ⣾  [+] 1m:14.0s
# Extracting  (33)  ⣾  [+] 1m:14.1s
# Extracting  (33)  ⣾  [+] 1m:14.2s
# Extracting  (33)  ⣾  [+] 1m:14.3s
# Extracting  (33)  ⣾  [+] 1m:14.4s
# Extracting  (33)  ⣾  [+] 1m:14.5s
# Extracting  (33)  ⣾  [+] 1m:14.6s
# Extracting  (33)  ⣾  [+] 1m:14.7s
# Extracting  (33)  ⣾  [+] 1m:14.8s
# Extracting  (33)  ⣾  [+] 1m:14.9s
# Extracting  (33)  ⣾  [+] 1m:15.0s
# Extracting  (33)  ⣾  [+] 1m:15.1s
# Extracting  (33)  ⣾  [+] 1m:15.2s
# Extracting  (33)  ⣾  [+] 1m:15.3s
# Extracting  (33)  ⣾  [+] 1m:15.4s
# Extracting  (33)  ⣾  [+] 1m:15.5s
# Extracting  (33)  ⣾  [+] 1m:15.6s
# Extracting  (33)  ⣾  [+] 1m:15.7s
# Extracting  (33)  ⣾  [+] 1m:15.8s
# Extracting  (33)  ⣾  [+] 1m:15.9s
# Extracting  (33)  ⣾  [+] 1m:16.0s
# Extracting  (33)  ⣾  [+] 1m:16.1s
# Extracting  (33)  ⣾  [+] 1m:16.2s
# Extracting  (33)  ⣾  [+] 1m:16.3s
# Extracting  (33)  ⣾  [+] 1m:16.4s
# Extracting  (33)  ⣾  [+] 1m:16.5s
# Extracting  (33)  ⣾  [+] 1m:16.6s
# Extracting  (33)  ⣾  [+] 1m:16.7s
# Extracting  (33)  ⣾  [+] 1m:16.8s
# Extracting  (33)  ⣾  [+] 1m:16.9s
# Extracting  (33)  ⣾  [+] 1m:17.0s
# Extracting  (33)  ⣾  [+] 1m:17.1s
# Extracting  (33)  ⣾  [+] 1m:17.2s
# Extracting  (33)  ⣾  [+] 1m:17.3s
# Extracting  (33)  ⣾  [+] 1m:17.4s
# Extracting  (33)  ⣾  [+] 1m:17.5s
# Extracting  (33)  ⣾  [+] 1m:17.6s
# Extracting  (33)  ⣾  [+] 1m:17.7s
# Extracting  (33)  ⣾  [+] 1m:17.8s
# Extracting  (33)  ⣾  [+] 1m:17.9s
# Extracting  (33)  ⣾  [+] 1m:18.0s
# Extracting  (33)  ⣾  [+] 1m:18.1s
# Extracting  (33)  ⣾  [+] 1m:18.2s
# Extracting  (33)  ⣾  [+] 1m:18.3s
# Extracting  (33)  ⣾  [+] 1m:18.4s
# Extracting  (33)  ⣾  [+] 1m:18.5s
# Extracting  (33)  ⣾  [+] 1m:18.6s
# Extracting  (33)  ⣾  [+] 1m:18.7s
# Extracting  (33)  ⣾  [+] 1m:18.8s
# Extracting  (33)  ⣾  [+] 1m:18.9s
# Extracting  (33)  ⣾  [+] 1m:19.0s
# Extracting  (33)  ⣾  [+] 1m:19.1s
# Extracting  (33)  ⣾  [+] 1m:19.2s
# Extracting  (33)  ⣾  [+] 1m:19.3s
# Extracting  (33)  ⣾  [+] 1m:19.4s
# Extracting  (33)  ⣾  [+] 1m:19.5s
# Extracting  (33)  ⣾  [+] 1m:19.6s
# Extracting  (33)  ⣾  [+] 1m:19.7s
# Extracting  (33)  ⣾  [+] 1m:19.8s
# Extracting  (33)  ⣾  [+] 1m:19.9s
# Extracting  (33)  ⣾  [+] 1m:20.0s
# Extracting  (33)  ⣾  [+] 1m:20.1s
# Extracting  (33)  ⣾  [+] 1m:20.2s
# Extracting  (33)  ⣾  [+] 1m:20.3s
# Extracting  (33)  ⣾  [+] 1m:20.4s
# Extracting  (33)  ⣾  [+] 1m:20.5s
# Extracting  (33)  ⣾  [+] 1m:20.6s
# Extracting  (33)  ⣾  [+] 1m:20.7s
# Extracting  (33)  ⣾  [+] 1m:20.8s
# Extracting  (33)  ⣾  [+] 1m:20.9s
# Extracting  (33)  ⣾  [+] 1m:21.0s
# Extracting  (33)  ⣾  [+] 1m:21.1s
# Extracting  (33)  ⣾  [+] 1m:21.2s
# Extracting  (33)  ⣾  [+] 1m:21.3s
# Extracting  (33)  ⣾  [+] 1m:21.4s
# Extracting  (33)  ⣾  [+] 1m:21.5s
# Extracting  (33)  ⣾  [+] 1m:21.6s
# Extracting  (33)  ⣾  [+] 1m:21.7s
# Extracting  (33)  ⣾  [+] 1m:21.8s
# Extracting  (33)  ⣾  [+] 1m:21.9s
# Extracting  (33)  ⣾  [+] 1m:22.0s
# Extracting  (33)  ⣾  [+] 1m:22.1s
# Extracting  (33)  ⣾  [+] 1m:22.2s
# Extracting  (33)  ⣾  [+] 1m:22.3s
# Extracting  (33)  ⣾  [+] 1m:22.4s
# Extracting  (33)  ⣾  [+] 1m:22.5s
# Extracting  (33)  ⣾  [+] 1m:22.6s
# Extracting  (33)  ⣾  [+] 1m:22.7s
# Extracting  (33)  ⣾  [+] 1m:22.8s
# Extracting  (33)  ⣾  [+] 1m:22.9s
# Extracting  (33)  ⣾  [+] 1m:23.0s
# Extracting  (33)  ⣾  [+] 1m:23.1s
# Extracting  (33)  ⣾  [+] 1m:23.2s
# Extracting  (33)  ⣾  [+] 1m:23.3s
# Extracting  (33)  ⣾  [+] 1m:23.4s
# Extracting  (33)  ⣾  [+] 1m:23.5s
# Extracting  (33)  ⣾  [+] 1m:23.6s
# Extracting  (33)  ⣾  [+] 1m:23.7s
# Extracting  (33)  ⣾  [+] 1m:23.8s
# Extracting  (33)  ⣾  [+] 1m:23.9s
# Extracting  (33)  ⣾  [+] 1m:24.0s
# Extracting  (33)  ⣾  [+] 1m:24.1s
# Extracting  (33)  ⣾  [+] 1m:24.2s
# Extracting  (33)  ⣾  [+] 1m:24.3s
# Extracting  (33)  ⣾  [+] 1m:24.4s
# Extracting  (33)  ⣾  [+] 1m:24.5s
# Extracting  (33)  ⣾  [+] 1m:24.6s
# Extracting  (33)  ⣾  [+] 1m:24.7s
# Extracting  (33)  ⣾  [+] 1m:24.8s
# Extracting  (33)  ⣾  [+] 1m:24.9s
# Extracting  (33)  ⣾  [+] 1m:25.0s
# Extracting  (33)  ⣾  [+] 1m:25.1s
# Extracting  (33)  ⣾  [+] 1m:25.2s
# Extracting  (33)  ⣾  [+] 1m:25.3s
# Extracting  (33)  ⣾  [+] 1m:25.4s
# Extracting  (33)  ⣾  [+] 1m:25.5s
# Extracting  (33)  ⣾  [+] 1m:25.6s
# Extracting  (33)  ⣾  [+] 1m:25.7s
# Extracting  (33)  ⣾  [+] 1m:25.8s
# Extracting  (33)  ⣾  [+] 1m:25.9s
# Extracting  (33)  ⣾  [+] 1m:26.0s
# Extracting  (33)  ⣾  [+] 1m:26.1s
# Extracting  (33)  ⣾  [+] 1m:26.2s
# Extracting  (33)  ⣾  [+] 1m:26.3s
# Extracting  (33)  ⣾  [+] 1m:26.4s
# Extracting  (33)  ⣾  [+] 1m:26.5s
# Extracting  (33)  ⣾  [+] 1m:26.6s
# Extracting  (33)  ⣾  [+] 1m:26.7s
# Extracting  (33)  ⣾  [+] 1m:26.8s
# Extracting  (33)  ⣾  [+] 1m:26.9s
# Extracting  (33)  ⣾  [+] 1m:27.0s
# Extracting  (33)  ⣾  [+] 1m:27.1s
# Extracting  (33)  ⣾  [+] 1m:27.2s
# Extracting  (33)  ⣾  [+] 1m:27.3s
# Extracting  (33)  ⣾  [+] 1m:27.4s
# Extracting  (33)  ⣾  [+] 1m:27.5s
# Extracting  (33)  ⣾  [+] 1m:27.6s
# Extracting  (33)  ⣾  [+] 1m:27.7s
# Extracting  (33)  ⣾  [+] 1m:27.8s
# Extracting  (33)  ⣾  [+] 1m:27.9s
# Extracting  (33)  ⣾  [+] 1m:28.0s
# Extracting  (33)  ⣾  [+] 1m:28.1s
# Extracting  (33)  ⣾  [+] 1m:28.2s
# Extracting  (33)  ⣾  [+] 1m:28.3s
# Extracting  (33)  ⣾  [+] 1m:28.4s
# Extracting  (33)  ⣾  [+] 1m:28.5s
# Extracting  (33)  ⣾  [+] 1m:28.6s
# Extracting  (33)  ⣾  [+] 1m:28.7s
# Extracting  (33)  ⣾  [+] 1m:28.8s
# Extracting  (33)  ⣾  [+] 1m:28.9s
# Extracting  (33)  ⣾  [+] 1m:29.0s
# Extracting  (33)  ⣾  [+] 1m:29.1s
# Extracting  (33)  ⣾  [+] 1m:29.2s
# Extracting  (33)  ⣾  [+] 1m:29.3s
# Extracting  (33)  ⣾  [+] 1m:29.4s
# Extracting  (33)  ⣾  [+] 1m:29.5s
# Extracting  (33)  ⣾  [+] 1m:29.6s
# Extracting  (33)  ⣾  [+] 1m:29.7s
# Extracting  (33)  ⣾  [+] 1m:29.8s
# Extracting  (33)  ⣾  [+] 1m:29.9s
# Extracting  (33)  ⣾  [+] 1m:30.0s
# Extracting  (33)  ⣾  [+] 1m:30.1s
# Extracting  (33)  ⣾  [+] 1m:30.2s
# Extracting  (33)  ⣾  [+] 1m:30.3s
# Extracting  (33)  ⣾  [+] 1m:30.4s
# Extracting  (33)  ⣾  [+] 1m:30.5s
# Extracting  (33)  ⣾  [+] 1m:30.6s
# Extracting  (33)  ⣾  [+] 1m:30.7s
# Extracting  (33)  ⣾  [+] 1m:30.8s
# Extracting  (33)  ⣾  [+] 1m:30.9s
# Extracting  (33)  ⣾  [+] 1m:31.0s
# Extracting  (33)  ⣾  [+] 1m:31.1s
# Extracting  (33)  ⣾  [+] 1m:31.2s
# Extracting  (33)  ⣾  [+] 1m:31.3s
# Extracting  (33)  ⣾  [+] 1m:31.4s
# Extracting  (33)  ⣾  [+] 1m:31.5s
# Extracting  (33)  ⣾  [+] 1m:31.6s
# Extracting  (33)  ⣾  [+] 1m:31.7s
# Extracting  (33)  ⣾  [+] 1m:31.8s
# Extracting  (33)  ⣾  [+] 1m:31.9s
# Extracting  (33)  ⣾  [+] 1m:32.0s
# Extracting  (33)  ⣾  [+] 1m:32.1s
# Extracting  (33)  ⣾  [+] 1m:32.2s
# Extracting  (33)  ⣾  [+] 1m:32.3s
# Extracting  (33)  ⣾  [+] 1m:32.4s
# Extracting  (33)  ⣾  [+] 1m:32.5s
# Extracting  (33)  ⣾  [+] 1m:32.6s
# Extracting  (33)  ⣾  [+] 1m:32.7s
# Extracting  (33)  ⣾  [+] 1m:32.8s
# Extracting  (33)  ⣾  [+] 1m:32.9s
# Extracting  (33)  ⣾  [+] 1m:33.0s
# Extracting  (33)  ⣾  [+] 1m:33.1s
# Extracting  (33)  ⣾  [+] 1m:33.2s
# Extracting  (33)  ⣾  [+] 1m:33.3s
# Extracting  (33)  ⣾  [+] 1m:33.4s
# Extracting  (33)  ⣾  [+] 1m:33.5s
# Extracting  (33)  ⣾  [+] 1m:33.6s
# Extracting  (33)  ⣾  [+] 1m:33.7s
# Extracting  (33)  ⣾  [+] 1m:33.8s
# Extracting  (33)  ⣾  [+] 1m:33.9s
# Extracting  (33)  ⣾  [+] 1m:34.0s
# Extracting  (33)  ⣾  [+] 1m:34.1s
# Extracting  (33)  ⣾  [+] 1m:34.2s
# Extracting  (33)  ⣾  [+] 1m:34.3s
# Extracting  (33)  ⣾  [+] 1m:34.4s
# Extracting  (33)  ⣾  [+] 1m:34.5s
# Extracting  (33)  ⣾  [+] 1m:34.6s
# Extracting  (33)  ⣾  [+] 1m:34.7s
# Extracting  (33)  ⣾  [+] 1m:34.8s
# Extracting  (33)  ⣾  [+] 1m:34.9s
# Extracting  (33)  ⣾  [+] 1m:35.0s
# Extracting  (33)  ⣾  [+] 1m:35.1s
# Extracting  (33)  ⣾  [+] 1m:35.2s
# Extracting  (33)  ⣾  [+] 1m:35.3s
# Extracting  (33)  ⣾  [+] 1m:35.4s
# Extracting  (33)  ⣾  [+] 1m:35.5s
# Extracting  (33)  ⣾  [+] 1m:35.6s
# Extracting  (33)  ⣾  [+] 1m:35.7s
# Extracting  (33)  ⣾  [+] 1m:35.8s
# Extracting  (33)  ⣾  [+] 1m:35.9s
# Extracting  (33)  ⣾  [+] 1m:36.0s
# Extracting  (33)  ⣾  [+] 1m:36.1s
# Extracting  (33)  ⣾  [+] 1m:36.2s
# Extracting  (33)  ⣾  [+] 1m:36.3s
# Extracting  (33)  ⣾  [+] 1m:36.4s
# Extracting  (33)  ⣾  [+] 1m:36.5s
# Extracting  (33)  ⣾  [+] 1m:36.6s
# Extracting  (33)  ⣾  [+] 1m:36.7s
# Extracting  (33)  ⣾  [+] 1m:36.8s
# Extracting  (33)  ⣾  [+] 1m:36.9s
# Extracting  (33)  ⣾  [+] 1m:37.0s
# Extracting  (33)  ⣾  [+] 1m:37.1s
# Extracting  (33)  ⣾  [+] 1m:37.2s
# Extracting  (33)  ⣾  [+] 1m:37.3s
# Extracting  (33)  ⣾  [+] 1m:37.4s
# Extracting  (33)  ⣾  [+] 1m:37.5s
# Extracting  (33)  ⣾  [+] 1m:37.6s
# Extracting  (33)  ⣾  [+] 1m:37.7s
# Extracting  (33)  ⣾  [+] 1m:37.8s
# Extracting  (33)  ⣾  [+] 1m:37.9s
# Extracting  (33)  ⣾  [+] 1m:38.0s
# Extracting  (33)  ⣾  [+] 1m:38.1s
# Extracting  (33)  ⣾  [+] 1m:38.2s
# Extracting  (33)  ⣾  [+] 1m:38.3s
# Extracting  (33)  ⣾  [+] 1m:38.4s
# Extracting  (33)  ⣾  [+] 1m:38.5s
# Extracting  (33)  ⣾  [+] 1m:38.6s
# Extracting  (33)  ⣾  [+] 1m:38.7s
# Extracting  (33)  ⣾  [+] 1m:38.8s
# Extracting  (33)  ⣾  [+] 1m:38.9s
# Extracting  (33)  ⣾  [+] 1m:39.0s
# Extracting  (33)  ⣾  [+] 1m:39.1s
# Extracting  (33)  ⣾  [+] 1m:39.2s
# Extracting  (33)  ⣾  [+] 1m:39.3s
# Extracting  (33)  ⣾  [+] 1m:39.4s
# Extracting  (33)  ⣾  [+] 1m:39.5s
# Extracting  (33)  ⣾  [+] 1m:39.6s
# Extracting  (33)  ⣾  [+] 1m:39.7s
# Extracting  (33)  ⣾  [+] 1m:39.8s
# Extracting  (33)  ⣾  [+] 1m:39.9s
# Extracting  (33)  ⣾  [+] 1m:40.0s
# Extracting  (33)  ⣾  [+] 1m:40.1s
# Extracting  (33)  ⣾  [+] 1m:40.2s
# Extracting  (33)  ⣾  [+] 1m:40.3s
# Extracting  (33)  ⣾  [+] 1m:40.4s
# Extracting  (33)  ⣾  [+] 1m:40.5s
# Extracting  (33)  ⣾  [+] 1m:40.6s
# Extracting  (33)  ⣾  [+] 1m:40.7s
# Extracting  (33)  ⣾  [+] 1m:40.8s
# Extracting  (33)  ⣾  [+] 1m:40.9s
# Extracting  (33)  ⣾  [+] 1m:41.0s
# Extracting  (33)  ⣾  [+] 1m:41.1s
# Extracting  (33)  ⣾  [+] 1m:41.2s
# Extracting  (33)  ⣾  [+] 1m:41.3s
# Extracting  (33)  ⣾  [+] 1m:41.4s
# Extracting  (33)  ⣾  [+] 1m:41.5s
# Extracting  (33)  ⣾  [+] 1m:41.6s
# Extracting  (33)  ⣾  [+] 1m:41.7s
# Extracting  (33)  ⣾  [+] 1m:41.8s
# Extracting  (33)  ⣾  [+] 1m:41.9s
# Extracting  (33)  ⣾  [+] 1m:42.0s
# Extracting  (33)  ⣾  [+] 1m:42.1s
# Extracting  (33)  ⣾  [+] 1m:42.2s
# Extracting  (33)  ⣾  [+] 1m:42.3s
# Extracting  (33)  ⣾  [+] 1m:42.4s
# Extracting  (33)  ⣾  [+] 1m:42.5s
# Extracting  (33)  ⣾  [+] 1m:42.6s
# Extracting  (32)  ⣾  [+] 1m:42.7s
# Extracting  (32)  ⣾  [+] 1m:42.8s
# Extracting  (32)  ⣾  [+] 1m:42.9s
# Extracting  (32)  ⣾  [+] 1m:43.0s
# Extracting  (32)  ⣾  [+] 1m:43.1s
# Extracting  (32)  ⣾  [+] 1m:43.2s
# Extracting  (32)  ⣾  [+] 1m:43.3s
# Extracting  (32)  ⣾  [+] 1m:43.4s
# Extracting  (32)  ⣾  [+] 1m:43.5s
# Extracting  (32)  ⣾  [+] 1m:43.6s
# Extracting  (32)  ⣾  [+] 1m:43.7s
# Extracting  (32)  ⣾  [+] 1m:43.8s
# Extracting  (32)  ⣾  [+] 1m:43.9s
# Extracting  (32)  ⣾  [+] 1m:44.0s
# Extracting  (32)  ⣾  [+] 1m:44.1s
# Extracting  (32)  ⣾  [+] 1m:44.2s
# Extracting  (32)  ⣾  [+] 1m:44.3s
# Extracting  (32)  ⣾  [+] 1m:44.4s
# Extracting  (32)  ⣾  [+] 1m:44.5s
# Extracting  (32)  ⣾  [+] 1m:44.6s
# Extracting  (32)  ⣾  [+] 1m:44.7s
# Extracting  (32)  ⣾  [+] 1m:44.8s
# Extracting  (32)  ⣾  [+] 1m:44.9s
# Extracting  (32)  ⣾  [+] 1m:45.0s
# Extracting  (32)  ⣾  [+] 1m:45.1s
# Extracting  (32)  ⣾  [+] 1m:45.2s
# Extracting  (32)  ⣾  [+] 1m:45.3s
# Extracting  (32)  ⣾  [+] 1m:45.4s
# Extracting  (32)  ⣾  [+] 1m:45.5s
# Extracting  (32)  ⣾  [+] 1m:45.6s
# Extracting  (32)  ⣾  [+] 1m:45.7s
# Extracting  (32)  ⣾  [+] 1m:45.8s
# Extracting  (32)  ⣾  [+] 1m:45.9s
# Extracting  (32)  ⣾  [+] 1m:46.0s
# Extracting  (32)  ⣾  [+] 1m:46.1s
# Extracting  (32)  ⣾  [+] 1m:46.2s
# Extracting  (32)  ⣾  [+] 1m:46.3s
# Extracting  (32)  ⣾  [+] 1m:46.4s
# Extracting  (32)  ⣾  [+] 1m:46.5s
# Extracting  (32)  ⣾  [+] 1m:46.6s
# Extracting  (32)  ⣾  [+] 1m:46.7s
# Extracting  (32)  ⣾  [+] 1m:46.8s
# Extracting  (32)  ⣾  [+] 1m:46.9s
# Extracting  (32)  ⣾  [+] 1m:47.0s
# Extracting  (32)  ⣾  [+] 1m:47.1s
# Extracting  (32)  ⣾  [+] 1m:47.2s
# Extracting  (32)  ⣾  [+] 1m:47.3s
# Extracting  (32)  ⣾  [+] 1m:47.4s
# Extracting  (32)  ⣾  [+] 1m:47.5s
# Extracting  (32)  ⣾  [+] 1m:47.6s
# Extracting  (32)  ⣾  [+] 1m:47.7s
# Extracting  (32)  ⣾  [+] 1m:47.8s
# Extracting  (32)  ⣾  [+] 1m:47.9s
# Extracting  (32)  ⣾  [+] 1m:48.0s
# Extracting  (32)  ⣾  [+] 1m:48.1s
# Extracting  (32)  ⣾  [+] 1m:48.2s
# Extracting  (32)  ⣾  [+] 1m:48.3s
# Extracting  (32)  ⣾  [+] 1m:48.4s
# Extracting  (32)  ⣾  [+] 1m:48.5s
# Extracting  (32)  ⣾  [+] 1m:48.6s
# Extracting  (32)  ⣾  [+] 1m:48.7s
# Extracting  (32)  ⣾  [+] 1m:48.8s
# Extracting  (32)  ⣾  [+] 1m:48.9s
# Extracting  (32)  ⣾  [+] 1m:49.0s
# Extracting  (32)  ⣾  [+] 1m:49.1s
# Extracting  (32)  ⣾  [+] 1m:49.2s
# Extracting  (32)  ⣾  [+] 1m:49.3s
# Extracting  (32)  ⣾  [+] 1m:49.4s
# Extracting  (32)  ⣾  [+] 1m:49.5s
# Extracting  (32)  ⣾  [+] 1m:49.6s
# Extracting  (32)  ⣾  [+] 1m:49.7s
# Extracting  (32)  ⣾  [+] 1m:49.8s
# Extracting  (32)  ⣾  [+] 1m:49.9s
# Extracting  (32)  ⣾  [+] 1m:50.0s
# Extracting  (32)  ⣾  [+] 1m:50.1s
# Extracting  (32)  ⣾  [+] 1m:50.2s
# Extracting  (32)  ⣾  [+] 1m:50.3s
# Extracting  (32)  ⣾  [+] 1m:50.4s
# Extracting  (32)  ⣾  [+] 1m:50.5s
# Extracting  (32)  ⣾  [+] 1m:50.6s
# Extracting  (32)  ⣾  [+] 1m:50.7s
# Extracting  (32)  ⣾  [+] 1m:50.8s
# Extracting  (32)  ⣾  [+] 1m:50.9s
# Extracting  (32)  ⣾  [+] 1m:51.0s
# Extracting  (32)  ⣾  [+] 1m:51.1s
# Extracting  (32)  ⣾  [+] 1m:51.2s
# Extracting  (32)  ⣾  [+] 1m:51.3s
# Extracting  (32)  ⣾  [+] 1m:51.4s
# Extracting  (32)  ⣾  [+] 1m:51.5s
# Extracting  (32)  ⣾  [+] 1m:51.6s
# Extracting  (32)  ⣾  [+] 1m:51.7s
# Extracting  (32)  ⣾  [+] 1m:51.8s
# Extracting  (32)  ⣾  [+] 1m:51.9s
# Extracting  (32)  ⣾  [+] 1m:52.0s
# Extracting  (32)  ⣾  [+] 1m:52.1s
# Extracting  (32)  ⣾  [+] 1m:52.2s
# Extracting  (32)  ⣾  [+] 1m:52.3s
# Extracting  (32)  ⣾  [+] 1m:52.4s
# Extracting  (32)  ⣾  [+] 1m:52.5s
# Extracting  (32)  ⣾  [+] 1m:52.6s
# Extracting  (32)  ⣾  [+] 1m:52.7s
# Extracting  (32)  ⣾  [+] 1m:52.8s
# Extracting  (32)  ⣾  [+] 1m:52.9s
# Extracting  (32)  ⣾  [+] 1m:53.0s
# Extracting  (32)  ⣾  [+] 1m:53.1s
# Extracting  (32)  ⣾  [+] 1m:53.2s
# Extracting  (32)  ⣾  [+] 1m:53.3s
# Extracting  (32)  ⣾  [+] 1m:53.4s
# Extracting  (32)  ⣾  [+] 1m:53.5s
# Extracting  (32)  ⣾  [+] 1m:53.6s
# Extracting  (32)  ⣾  [+] 1m:53.7s
# Extracting  (32)  ⣾  [+] 1m:53.8s
# Extracting  (32)  ⣾  [+] 1m:53.9s
# Extracting  (32)  ⣾  [+] 1m:54.0s
# Extracting  (32)  ⣾  [+] 1m:54.1s
# Extracting  (32)  ⣾  [+] 1m:54.2s
# Extracting  (32)  ⣾  [+] 1m:54.3s
# Extracting  (32)  ⣾  [+] 1m:54.4s
# Extracting  (32)  ⣾  [+] 1m:54.5s
# Extracting  (32)  ⣾  [+] 1m:54.6s
# Extracting  (32)  ⣾  [+] 1m:54.7s
# Extracting  (32)  ⣾  [+] 1m:54.8s
# Extracting  (32)  ⣾  [+] 1m:54.9s
# Extracting  (32)  ⣾  [+] 1m:55.0s
# Extracting  (32)  ⣾  [+] 1m:55.1s
# Extracting  (32)  ⣾  [+] 1m:55.2s
# Extracting  (32)  ⣾  [+] 1m:55.3s
# Extracting  (32)  ⣾  [+] 1m:55.4s
# Extracting  (32)  ⣾  [+] 1m:55.5s
# Extracting  (32)  ⣾  [+] 1m:55.6s
# Extracting  (32)  ⣾  [+] 1m:55.7s
# Extracting  (32)  ⣾  [+] 1m:55.8s
# Extracting  (32)  ⣾  [+] 1m:55.9s
# Extracting  (32)  ⣾  [+] 1m:56.0s
# Extracting  (32)  ⣾  [+] 1m:56.1s
# Extracting  (32)  ⣾  [+] 1m:56.2s
# Extracting  (32)  ⣾  [+] 1m:56.3s
# Extracting  (32)  ⣾  [+] 1m:56.4s
# Extracting  (32)  ⣾  [+] 1m:56.5s
# Extracting  (32)  ⣾  [+] 1m:56.6s
# Extracting  (31)  ⣾  [+] 1m:56.7s
# Extracting  (31)  ⣾  [+] 1m:56.8s
# Extracting  (30)  ⣾  [+] 1m:56.9s
# Extracting  (29)  ⣾  [+] 1m:57.0s
# Extracting  (28)  ⣾  [+] 1m:57.1s
# Extracting  (28)  ⣾  [+] 1m:57.2s
# Extracting  (28)  ⣾  [+] 1m:57.3s
# Extracting  (28)  ⣾  [+] 1m:57.4s
# Extracting  (28)  ⣾  [+] 1m:57.5s
# Extracting  (28)  ⣾  [+] 1m:57.6s
# Extracting  (28)  ⣾  [+] 1m:57.7s
# Extracting  (28)  ⣾

# %%
import os
os._exit(0)

# %%
import cudf
import rmm
from rmm.allocators.proxy import ProxyAllocator

# Configura o pool de memória do RMM
# Recomendado: cerca de metade da VRAM disponível
rmm.reinitialize(
    pool_allocator=True,
    initial_pool_size="8GB",
    devices=[0]
)

print("RMM inicializado com sucesso!")
print(f"Versão do cuDF: {cudf.__version__}")

# %% [markdown]
# ## 📥 Load Dataset
#
# When we work with giant datasets, traditional pandas often runs out of memory or slows down dramatically.
# To solve this, we’ll load our data with **cuDF Pandas**, which runs the good old Pandas commands — just on the GPU! 🐼
#
# It’s a simple one-line switch that gives us full GPU acceleration with no code changes. So instead of chunking or splitting our files to run on CPU, we can just load millions of rows smoothly, keeping the workflow clean and professional.

# %%
import os
import pandas as pd

# URL oficial do NYC Taxi Data (Janeiro 2023)
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet"
file_path = "yellow_tripdata_2023-01.parquet"

if not os.path.exists(file_path):
    print("Baixando dados reais do NYC Taxi...")
    # !wget -q {url} -O {file_path}

try:
    # Tentativa de usar cuDF se estiver disponível
    import cudf
    data = cudf.read_parquet(file_path)
    print("Dados carregados com sucesso via GPU (cuDF)!")
except Exception:
    # Fallback para Pandas padrão
    data = pd.read_parquet(file_path)
    print("Aviso: cuDF indisponível. Dados carregados via CPU (Pandas).")

# Reduzindo o dataset para manter a agilidade no tutorial
data = data.head(1000000)
display(data.tail())
# Out:
# Baixando dados reais do NYC Taxi...
# Aviso: cuDF indisponível. Dados carregados via CPU (Pandas).
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 999995         1  2023-01-12 08:44:15   2023-01-12 09:39:58              1.0
# 999996         2  2023-01-12 08:20:16   2023-01-12 08:26:09              1.0
# 999997         2  2023-01-12 09:01:08   2023-01-12 09:09:41              1.0
# 999998         1  2023-01-12 08:58:14   2023-01-12 09:07:32              1.0
# 999999         1  2023-01-12 08:09:21   2023-01-12 08:21:07              1.0
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 999995          13.00         2.0                  N           215
# 999996           0.54         1.0                  N           237
# 999997           1.25         1.0                  N           234
# 999998           1.30         1.0                  N           264
# 999999           2.20         1.0                  N           236
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 999995           264             1         70.0    2.5      0.5       16.10
# 999996           141             1          7.2    0.0      0.5        2.24
# 999997           114             1         10.0    0.0      0.5        1.00
# 999998            75             1         10.7    0.0      0.5        2.00
# 999999           161             1         13.5    2.5      0.5        3.50
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 999995          6.55                    1.0         96.65
# 999996          0.00                    1.0         13.44
# 999997          0.00                    1.0         15.00
# 999998          0.00                    1.0         14.20
# 999999          0.00                    1.0         21.00
#
#         congestion_surcharge  airport_fee
# 999995                   2.5          0.0
# 999996                   2.5          0.0
# 999997                   2.5          0.0
# 999998                   0.0          0.0
# 999999                   2.5          0.0

# %% [markdown]
# ## 🧹 Initial Cleanup - Missing Values
#
# ### Find Missing Values 🔎
# Before we clean anything, we first need to know how bad the damage is. Let’s check **how many missing values we have in each column** — this gives us a clear picture of what needs fixing, and what we can safely ignore.
#
# Once we know where the gaps are, we can decide how to handle them.

# %%
data.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# airport_fee              0
# dtype: int64

# %% [markdown]
# ### Replace Missing Values 🔧
#
# Not all missing values mean the same thing — so we handle each column based on logic, not guesswork or laziness!
#
# If a **fee** is missing, it probably means the passenger didn’t pay that fee at all, so we can that the **fee is 0**.
# But if something like the **passenger count** is missing, it doesn’t mean there were no passengers — it’s more likely that the driver simply **forgot to enter it**.
#
# That’s why we treat each case differently, using common sense before touching the data.
# Specifically: `RatecodeID` stores <a target="_blank" href="https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf">internal labels</a> where the lable for "unknown" is 99. So we replace the missing values in that column with 99.
# <br>
# But when it comes to `store_and_fwd_flag`, since it stores information that neither the driver nor the passenger is aware of - it has no chance of affecting the size of tip, and therefore we delete this column altogether.

# %%
# Preenchimento preventivo e limpeza conforme planejado
data['airport_fee'] = data['airport_fee'].fillna(0)
data['congestion_surcharge'] = data['congestion_surcharge'].fillna(0)
data['passenger_count'] = data['passenger_count'].fillna(data['passenger_count'].mean())
data['RatecodeID'] = data['RatecodeID'].fillna(99)

# Remoção de coluna irrelevante para o modelo
data = data.drop(columns=['store_and_fwd_flag'])

print('Limpeza inicial concluída!')
# Out:
# Limpeza inicial concluída!

# %% [markdown]
# ### Verify Values Were Replaced ✅
# Before moving forward, let’s double-check that all missing values were actually filled. It’s always good practice to confirm the cleanup worked before we continue — otherwise, those gaps might cause errors later during training.

# %%
data.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# airport_fee              0
# dtype: int64

# %% [markdown]
# ## 🤖 Machine Learning
#
# ### Train and Test Split 🖖
#
# Before we train anything, we need to **split our data into two parts** — one for training, and one for testing.
# The model learns patterns from the training examples, and then we check how well it performs on new, unseen examples — the test data.
#
# We’ll also separate **targets** (the values we want to predict, in our case, the tip amount) from **features** (the rest of the columns). The bigger portion always goes to training, because the more examples the model sees, the better it can learn real-world patterns.

# %%
def train_test_split(data):
    # Embaralhar o dataset para garantir aleatoriedade
    data = data.sample(frac=1, random_state=432).reset_index(drop=True)

    # Extrair alvo (tip_amount) e remover colunas temporais que não usaremos agora
    targets = data["tip_amount"]
    features = data.drop(columns=["tip_amount", "tpep_pickup_datetime", "tpep_dropoff_datetime"])

    # Dividir: usaremos 80% para treino e 20% para teste
    split_idx = int(len(data) * 0.8)
    x_train, x_test = features.iloc[:split_idx], features.iloc[split_idx:]
    y_train, y_test = targets.iloc[:split_idx], targets.iloc[split_idx:]

    return x_train, x_test, y_train, y_test

x_train, x_test, y_train, y_test = train_test_split(data)
print(f"Treino: {x_train.shape[0]} linhas | Teste: {x_test.shape[0]} linhas")
# Out:
# Treino: 800000 linhas | Teste: 200000 linhas

# %% [markdown]
# ### Train Model 🧠
#
# Now it’s time to train our model using XGBoost — one of the fastest and most reliable machine learning algorithms out there! To keep it fast, we will use our model to use `device="cuda"` - and that way we can leverage our GPU not only for data sceince - but also for machine learning.
#
# So in the cell below, **training will update our model** and makes it smarter, while **testing will check that the model learned rather than memorized**. For training, we give our model the entire learning material - a bunch of questions (train features) along with matching answers (train targets). At testing, we give our model only the exam questions (test features), and we let it figure out the exam answers on its own! we just let it predict them. Then, to evaluate it, we compare the predictions with the actual values from the dataset (test targets) to see just how well our model performs.
#
# In our case, in the function below, we bundle training with testing, retrieving the trained model, along with its' predicted "exam answer sheet".

# %%
from xgboost import XGBRegressor

def training_run(x_train, y_train, x_test):
    # Criar modelo configurado para GPU
    model = XGBRegressor(device="cuda", enable_categorical=True)
    # Treinar o modelo
    model.fit(x_train, y_train)
    # Fazer previsões no conjunto de teste
    predictions = model.predict(x_test)
    return model, predictions

model1, predictions = training_run(x_train, y_train, x_test)
print("Treinamento do Modelo 1 concluído!")
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [15:34:47] WARNING: /__w/xgboost/xgboost/src/context.cc:53: No visible GPU is found, setting device to CPU.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [15:34:47] WARNING: /__w/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# Treinamento do Modelo 1 concluído!

# %% [markdown]
# ### Evaluate Model 📏
#
# Now that our model made its predictions, we need a way to measure how accurate they are.
# For that, we’ll use a metric called **Mean Squared Error (MSE)** — it calculates how far our predictions are from the real values. The smaller the number, the smaller the difference between the prediction and the actual value — meaning our model gets smarter!
#
# We’ll use this score to track how much our results improve as we keep cleaning and optimizing the data.
# We call our initial score a **baseline**.

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, predictions)
print(f"Mean Squared Error (Baseline): {mse}")
# Out:
# Mean Squared Error (Baseline): 0.871629946024091

# %% [markdown]
# ### Discuss Results 🔉
#
# MSE of 1.12 means that our model is **wrong by 1.12 USD** on average, so if the model predicts that the tip should be 2.50 USD - then the actual tip is either 3.62 or 1.38 USD.

# %% [markdown]
# ## 💪 Data Optimization
#
# ### Find Anomalies 🔎
# Now that our model works, it’s time to make our data even cleaner and more reliable.
# We’ll start by summarizing the dataset — checking the minimum, maximum, and average for every numeric column.
#
# This quick scan helps us spot anything that doesn’t make sense, like negative fares, impossible distances, or other strange outliers.

# %%
data.select_dtypes(include="number").agg(["min", "max", "mean"]).T
# Out:
#                           min       max        mean
# VendorID                 1.00      2.00    1.733920
# passenger_count          0.00      6.00    1.385793
# trip_distance            0.00  62359.52    3.657844
# RatecodeID               1.00     99.00    1.548008
# PULocationID             1.00    265.00  165.997293
# DOLocationID             1.00    265.00  163.871838
# payment_type             1.00      4.00    1.242385
# fare_amount           -580.00    999.00   18.838273
# extra                   -7.50     11.25    1.564112
# mta_tax                 -0.50     53.16    0.487302
# tip_amount             -33.93    211.50    3.331161
# tolls_amount           -65.00     86.55    0.558295
# improvement_surcharge   -1.00      1.00    0.980632
# total_amount          -583.50   1000.00   27.498726
# congestion_surcharge    -2.50      2.50    2.247370
# airport_fee             -1.25      1.25    0.121309

# %% [markdown]
# ### Handle Anomalies 🚦
# Some values in real-world data simply don’t make sense — and it’s our job to catch them!
# - A negative charge is probably a refund.
# - A trip distance of 0 means there was no actual trip
# - A distance of hundreds of thousands of miles is clearly an input error.
#
# To fix this, we’ll remove unrealistic rows and keep only the sensible ranges — for example, trips longer than half a mile but still within reasonable driving distance (that we get to decide! 😉). This helps the model focus on real, meaningful examples while ignoring the noise.

# %%
data = data[data["trip_distance"] > 0.5]
data = data[data["trip_distance"] < 100]
data = data[~data.select_dtypes("number").lt(0).any(axis=1)]

# %% [markdown]
# ### Verify Anomaly Handling ✅
# After cleaning, let’s double-check that the anomalies are actually gone.

# %%
data.select_dtypes(include="number").agg(["min", "max", "mean"]).T
# Out:
#                         min     max        mean
# VendorID               1.00    2.00    1.737313
# passenger_count        0.00    6.00    1.389907
# trip_distance          0.51   93.05    3.747319
# RatecodeID             1.00   99.00    1.481122
# PULocationID           1.00  265.00  165.782553
# DOLocationID           1.00  265.00  163.502484
# payment_type           1.00    4.00    1.211216
# fare_amount            0.00  580.00   19.514834
# extra                  0.00   11.25    1.597309
# mta_tax                0.00   53.16    0.497472
# tip_amount             0.00  211.50    3.442292
# tolls_amount           0.00   86.55    0.585312
# improvement_surcharge  0.00    1.00    0.998346
# total_amount           0.00  583.50   28.432949
# congestion_surcharge   0.00    2.50    2.299301
# airport_fee            0.00    1.25    0.128224

# %% [markdown]
# ### Handle Total Amount Anomaly 💳
#
# Every yellow cab trip starts with a base fare of 3.00 USD, plus about 0.70 USD per mile, per <a href="https://www.nyc.gov/site/tlc/passengers/taxi-fare.page" target="_blank">NYC official website</a>.
# Since we’ve already set a minimum trip distance of 0.5 miles, the lowest possible total fare should be around $3.70.
#
# So if we see anything lower than that, it’s safe to assume it’s not a real trip — maybe a data entry error, or a customer who never showed up, or just a broken record.

# %%
data = data[data["total_amount"] > 3.7]

# %%
# verify new total amount
data.select_dtypes(include="number").agg(["min", "max", "mean"]).T
# Out:
#                         min     max        mean
# VendorID               1.00    2.00    1.737353
# passenger_count        0.00    6.00    1.389916
# trip_distance          0.51   93.05    3.747054
# RatecodeID             1.00   99.00    1.480893
# PULocationID           1.00  265.00  165.783687
# DOLocationID           1.00  265.00  163.503188
# payment_type           1.00    4.00    1.211103
# fare_amount            0.00  580.00   19.516100
# extra                  0.00   11.25    1.597409
# mta_tax                0.00   53.16    0.497500
# tip_amount             0.00  211.50    3.442515
# tolls_amount           0.00   86.55    0.585350
# improvement_surcharge  0.00    1.00    0.998364
# total_amount           4.00  583.50   28.434732
# congestion_surcharge   0.00    2.50    2.299451
# airport_fee            0.00    1.25    0.128222

# %% [markdown]
# ## 💪 Second Training Run
#
# Now that we’ve cleaned up the data and removed anomalies, it’s time to retrain the model and see how much it improved. This is where all that careful data cleaning is supposed to pay off!

# %%
# new train and test split
x_train, x_test, y_train, y_test = train_test_split(data)
# train model
model2, predictions = training_run(x_train, y_train, x_test)
# evaluate model
mse = mean_squared_error(y_test, predictions)
mse
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [15:37:37] WARNING: /__w/xgboost/xgboost/src/context.cc:53: No visible GPU is found, setting device to CPU.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [15:37:37] WARNING: /__w/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# 0.7577811686540014

# %% [markdown]
# ### Compare to Baseline 🎖️
# Wow! 0.82 is much lower than 1.12! The model is now wrong by only 0.8 cents on average!

# %% [markdown]
# ## 📅 Handle Dates
#
# ### Extract Date Data
# Dates often hold a lot of hidden information like day of the week, hour of the day, or even month of the year — all of which can influence how people behave. Maybe we're more generous around Christmas? 🎄
# So far, we've put them aside because they were stored as strings and not numbers. But now we will convert these strings into actual date timestamps — allowing us to **extract all date and time-related features** easily, storing them as numbers! For example: 12 months, 7 days, AM/PM, 24 hours, 60 minutes, 60 seconds.
#
# We also calculate **new features** like the trip duration. We didn't know it before, but now it's very easy to extract it from the numeric dates.

# %%
# pick date/time format
date_format = "%Y-%m-%d %H:%M:%S"

# apply date/time format on pickup and dropoff time
data["tpep_pickup_datetime"] = pd.to_datetime(data["tpep_pickup_datetime"])
data["tpep_dropoff_datetime"] = pd.to_datetime(data["tpep_dropoff_datetime"])

# store month and day of week data separately
data["pickup_month"] = data["tpep_pickup_datetime"].dt.month
data["dropoff_month"] = data["tpep_dropoff_datetime"].dt.month
data["pickup_dow"] = data["tpep_pickup_datetime"].dt.dayofweek
data["dropoff_dow"] = data["tpep_dropoff_datetime"].dt.dayofweek

# extract trip duration in minutes
diff = data["tpep_dropoff_datetime"] - data["tpep_pickup_datetime"]
data["trip_duration_min"] = (diff.dt.total_seconds() / 60).astype("float32")

# verify min/max/mean for new columns
data[["pickup_month", "pickup_dow", "trip_duration_min"]].agg(["min", "max", "mean"]).T
# Out:
#                    min          max       mean
# pickup_month       1.0    12.000000   1.000296
# pickup_dow         0.0     6.000000   2.774509
# trip_duration_min  0.0  3040.516602  16.178509

# %% [markdown]
# ### ⏱️ Handle Trip Duration Anomalies
#
# Sometimes trip durations can be way too short or unrealistically long — usually because of data entry errors or GPS glitches. We’ll fix it by **removing rows** with values that fall outside a realistic range — once a record breaks basic logic, can you really trust it?
# - Since our minimum **trip distance is 0.5 miles**, the trip duration should be **at least 1 minute**.
# - And if the trip is around **100 miles**, there’s no way it should take **7,053 minutes** — that’s almost five days!
#
# Let's fix it.

# %%
data = data[data["trip_duration_min"] > 1]
data = data[data["trip_duration_min"] < 120]

display(data["trip_duration_min"].agg(["min", "max", "mean"]).T)
# Out:
# min       1.016667
# max     119.800003
# mean     14.817912
# Name: trip_duration_min, dtype: float64

# %% [markdown]
# ## 💪 Third Train Run
# Time for another training round! Now that we’ve fixed anomalies and added new features, we can see how much our model has improved.

# %%
# new train and test split
x_train, x_test, y_train, y_test = train_test_split(data)
# train model
model3, predictions = training_run(x_train, y_train, x_test)
# evaluate model
mse = mean_squared_error(y_test, predictions)
mse
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [15:38:55] WARNING: /__w/xgboost/xgboost/src/context.cc:53: No visible GPU is found, setting device to CPU.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [15:38:55] WARNING: /__w/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# 0.7047372840241249

# %% [markdown]
# ### Compare Results 🎖️
#
# Oh no! Our model did not improve this time - but in fact, it got weaker! 😭
# Let's try plotting the results of our training to see what's going on...
#
# ### Visualise Training Results - Feature Importance 📊
# What feature affects the tip the most? With XGBoost we can get that information directly from our model - as soon as it's done training. <br>We will plot it below with Matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# fetch feature importance from model
booster = model3.get_booster()
importance = booster.get_score(importance_type='weight')

# convert to DataFrame
importance_df = pd.DataFrame({
    'Feature': list(importance.keys()),
    'Importance': list(importance.values())
})

# sort by importance
importance_df = importance_df.sort_values(
    by='Importance',
    ascending=False
)

# plot data
ax = importance_df.plot(
    kind='bar',
    x='Feature',
    y='Importance',
    legend=False,
    figsize=(12, 6)
)

plt.title('Feature Importance (Model 3)')
plt.ylabel('Importance Score')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Discuss Feature Importance
# We see that the **most important features**, by far, are the **total amount** and the **fare amount** - both relate to the total trip charge. On the other hand, the **date features** we extracted so carefully earlier - are **are among the least important features** when it comes to tips.
#
# ### Plot Feature Importance For All Models
# We can also check if our previous models show different results (just remember - the previous models know nothing of dates! We only shared them with the third model).

# %%
import pandas as pd
import matplotlib.pyplot as plt

models = [model1, model2, model3]
names = ['Model 1', 'Model 2', 'Model 3']

def get_importance_df(model, name):
    """
    get feature important from model
    """
    booster = model.get_booster()
    imp = booster.get_score(importance_type='weight')
    df = pd.DataFrame({
        'Feature': list(imp.keys()),
        name: list(imp.values())
    })
    return df

# combine importances from all models
dfs = [get_importance_df(m, n) for m, n in zip(models, names)]
merged = dfs[0]

for df in dfs[1:]:
    merged = merged.merge(df, on='Feature', how='outer').fillna(0)

# Sort by one model or by mean importance
merged = merged.set_index('Feature')
merged = merged.sort_values(by=names[0], ascending=False).head(30)

# plot side-by-side bars
ax = merged.plot(
    kind='bar',
    figsize=(14, 6)
)

plt.title('Feature Importance Comparison Across Models')
plt.ylabel('Importance Score')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Model')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Criar DataFrame de comparação
comparison_df = pd.DataFrame({
    'Valor Real (y_test)': y_test.values,
    'Previsão (predictions)': predictions
})

print("Amostra de 10 comparações (Modelo 3):")
display(comparison_df.head(10))

# Visualização Gráfica
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Valor Real (y_test)', y='Previsão (predictions)', data=comparison_df.sample(2000, random_state=42), alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r', linewidth=2)
plt.title('Valores Reais vs. Previsões (Modelo 3)')
plt.xlabel('Valor Real da Gorjeta ($)')
plt.ylabel('Previsão do Modelo ($)')
plt.grid(True)
plt.show()
# Out:
# Amostra de 10 comparações (Modelo 3):
#    Valor Real (y_test)  Previsão (predictions)
# 0                 0.00                1.413047
# 1                 2.66                2.656108
# 2                 0.00               -0.215066
# 3                 2.00                2.344467
# 4                 3.50                3.550175
# 5                 5.00                4.794562
# 6                 2.35                2.338162
# 7                16.11               16.127333
# 8                 0.00                0.074485
# 9                 1.00                1.026518

# %% [markdown]
# ### Discuss Feature Importance For All Models Results
#
# We see that the importance of features remains consistent for all models. There are no drastic changes, and nothing really stands out.
#
# ## Keep Exploring 🧭
# Now it's your turn to keep exploring this dataset further and getting better and better scores every time! Best of luck, and I hope you enjoyed this workflow!
#
# See you in the next tutorial! 👋
# Mariya Sha
